# %%
import requests
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import os

# %%
# Load the Delaware dry land shapefile as a GeoDataFrame
USmap = gpd.read_file("/Users/kamran/Downloads/Shapefiles/cb_2018_us_state_5m/cb_2018_us_state_5m.shp")

# %% [markdown]
# # Extracting for a range of years

# %%
for i in range(2014,2022):
    year = str(i)
    
    usr_key = os.environ.get('CENSUS_API_KEY')

    host = 'https://api.census.gov/data'
    dataset_acronym = '/acs/acs5'
    g = '?get='
    variables = 'NAME,B01001_001E'
    location = '&for=state%20legislative%20district%20(lower%20chamber):*&in=state:10'

    # Put it all together in one f-string:
    query_url = f"{host}/{year}{dataset_acronym}{g}{variables}{location}&key={usr_key}"

    response = requests.get(query_url)

    # Create shapefile query URL
    shape_url = f"https://www2.census.gov/geo/tiger/TIGER{year}/SLDL/tl_{year}_10_sldl.zip"

    # Read the shapefile from the URL into a GeoPandas DataFrame
    sldl_gdf = gpd.read_file(shape_url)

    # Check if the request was successful (status code 200)
    if response.status_code == 200:

        # Convert the JSON response to a list of lists (excluding the header)
        data = response.json()[1:]

        # Convert the list of lists into a DataFrame
        columns = response.json()[0]  # Use the first row as column names
        api_data_df = pd.DataFrame(data, columns=columns)
        print(api_data_df.head())

        # Spatial intersection to retain only the parts within the dry land of Delaware
        delaware_land_gdf = gpd.overlay(sldl_gdf, USmap, how='intersection')

        # Dissolve the GeoDataFrame based on the SLDUST column to eliminate duplicates
        delaware_land_gdf = delaware_land_gdf.dissolve(by='SLDLST', aggfunc='first')        
        
        # Merge the DataFrame with the GeoDataFrame based on the common key and modify
        output_gdf = delaware_land_gdf.merge(api_data_df, left_on="SLDLST", right_on="state legislative district (lower chamber)")
        output_gdf = output_gdf[['geometry','B01001_001E','state legislative district (lower chamber)']]
        output_gdf.rename(columns={'B01001_001E':'Estimated Population','state legislative district (lower chamber)':'District'},inplace=True)
        output_gdf = output_gdf.astype({'Estimated Population':'int64','District':'int64'})
        
        # Save the merged GeoDataFrame as a GeoJSON file
        output_file = f"./DSHA_Population_SLDL_all_years/Population_SLDL_{year}.json"
        output_gdf.to_file(output_file, driver='GeoJSON')

        # Plot the merged GeoDataFrame with the added information from the DataFrame
        fig, ax = plt.subplots(figsize=(10, 10))
        output_gdf.plot(column="Estimated Population", cmap="OrRd", legend=True, ax=ax)
        ax.set_title(f"Estimated Population in State Legislative District Lower ({year})", fontsize=16)
    else:
        print("Error: Unable to fetch data from the API.")

    plt.savefig(f"./DSHA_Population_SLDL_all_years/population_sldl_{year}.png", dpi=300)
# Out:
#                                       NAME B01001_001E state  \
# 0  State House District 1 (2014), Delaware       22027    10
# 1  State House District 5 (2014), Delaware       22179    10
# 2  State House District 2 (2014), Delaware       20772    10
# 3  State House District 3 (2014), Delaware       21361    10
# 4  State House District 4 (2014), Delaware       22096    10
#
#   state legislative district (lower chamber)
# 0                                        001
# 1                                        005
# 2                                        002
# 3                                        003
# 4                                        004
# /Users/kamran/anaconda3/envs/census/lib/python3.10/site-packages/shapely/set_operations.py:133: RuntimeWarning: invalid value encountered in intersection
#   return lib.intersection(a, b, **kwargs)
# /var/folders/75/y16smf2j5032r_8n2vhxct6r0000gn/T/ipykernel_29732/2378207178.py:35: UserWarning: `keep_geom_type=True` in overlay resulted in 20 dropped geometries of different geometry types than df1 has. Set `keep_geom_type=False` to retain all geometries
#   delaware_land_gdf = gpd.overlay(sldl_gdf, USmap, how='intersection')
#                                       NAME B01001_001E state  \
# 0  State House District 1 (2014), Delaware       22799    10
# 1  State House District 2 (2014), Delaware       20967    10
# 2  State House District 3 (2014), Delaware       21168    10
# 3  State House District 4 (2014), Delaware       21915    10
# 4  State House District 5 (2014), Delaware       22313    10
#
#   state legislative district (lower chamber)
# 0                                        001
# 1                                        002
# 2                                        003
# 3                                        004
# 4                                        005
# /Users/kamran/anaconda3/envs/census/lib/python3.10/site-packages/shapely/set_operations.py:133: RuntimeWarning: invalid value encountered in intersection
#   return lib.intersection(a, b, **kwargs)
# /var/folders/75/y16smf2j5032r_8n2vhxct6r0000gn/T/ipykernel_29732/2378207178.py:35: UserWarning: `keep_geom_type=True` in overlay resulted in 20 dropped geometries of different geometry types than df1 has. Set `keep_geom_type=False` to retain all geometries
#   delaware_land_gdf = gpd.overlay(sldl_gdf, USmap, how='intersection')
#                                       NAME B01001_001E state  \
# 0  State House District 1 (2016), Delaware       22322    10
# 1  State House District 2 (2016), Delaware       21025    10
# 2  State House District 3 (2016), Delaware       21271    10
# 3  State House District 4 (2016), Delaware       22002    10
# 4  State House District 5 (2016), Delaware       22993    10
#
#   state legislative district (lower chamber)
# 0                                        001
# 1                                        002
# 2                                        003
# 3                                        004
# 4                                        005
# /Users/kamran/anaconda3/envs/census/lib/python3.10/site-packages/shapely/set_operations.py:133: RuntimeWarning: invalid value encountered in intersection
#   return lib.intersection(a, b, **kwargs)
# /var/folders/75/y16smf2j5032r_8n2vhxct6r0000gn/T/ipykernel_29732/2378207178.py:35: UserWarning: `keep_geom_type=True` in overlay resulted in 20 dropped geometries of different geometry types than df1 has. Set `keep_geom_type=False` to retain all geometries
#   delaware_land_gdf = gpd.overlay(sldl_gdf, USmap, how='intersection')
#                                       NAME B01001_001E state  \
# 0  State House District 1 (2016), Delaware       22303    10
# 1  State House District 2 (2016), Delaware       21172    10
# 2  State House District 3 (2016), Delaware       20525    10
# 3  State House District 4 (2016), Delaware       22039    10
# 4  State House District 5 (2016), Delaware       23678    10
#
#   state legislative district (lower chamber)
# 0                                        001
# 1                                        002
# 2                                        003
# 3                                        004
# 4                                        005
# /Users/kamran/anaconda3/envs/census/lib/python3.10/site-packages/shapely/set_operations.py:133: RuntimeWarning: invalid value encountered in intersection
#   return lib.intersection(a, b, **kwargs)
# /var/folders/75/y16smf2j5032r_8n2vhxct6r0000gn/T/ipykernel_29732/2378207178.py:35: UserWarning: `keep_geom_type=True` in overlay resulted in 20 dropped geometries of different geometry types than df1 has. Set `keep_geom_type=False` to retain all geometries
#   delaware_land_gdf = gpd.overlay(sldl_gdf, USmap, how='intersection')
#                                        NAME B01001_001E state  \
# 0   State House District 4 (2018), Delaware       22319    10
# 1  State House District 28 (2018), Delaware       22785    10
# 2  State House District 11 (2018), Delaware       21237    10
# 3  State House District 32 (2018), Delaware       24091    10
# 4  State House District 18 (2018), Delaware       22233    10
#
#   state legislative district (lower chamber)
# 0                                        004
# 1                                        028
# 2                                        011
# 3                                        032
# 4                                        018
# /Users/kamran/anaconda3/envs/census/lib/python3.10/site-packages/shapely/set_operations.py:133: RuntimeWarning: invalid value encountered in intersection
#   return lib.intersection(a, b, **kwargs)
# /var/folders/75/y16smf2j5032r_8n2vhxct6r0000gn/T/ipykernel_29732/2378207178.py:35: UserWarning: `keep_geom_type=True` in overlay resulted in 20 dropped geometries of different geometry types than df1 has. Set `keep_geom_type=False` to retain all geometries
#   delaware_land_gdf = gpd.overlay(sldl_gdf, USmap, how='intersection')
#                                        NAME B01001_001E state  \
# 0   State House District 4 (2018), Delaware       21938    10
# 1  State House District 28 (2018), Delaware       22945    10
# 2  State House District 11 (2018), Delaware       21592    10
# 3  State House District 32 (2018), Delaware       24263    10
# 4  State House District 18 (2018), Delaware       22799    10
#
#   state legislative district (lower chamber)
# 0                                        004
# 1                                        028
# 2                                        011
# 3                                        032
# 4                                        018
# /Users/kamran/anaconda3/envs/census/lib/python3.10/site-packages/shapely/set_operations.py:133: RuntimeWarning: invalid value encountered in intersection
#   return lib.intersection(a, b, **kwargs)
# /var/folders/75/y16smf2j5032r_8n2vhxct6r0000gn/T/ipykernel_29732/2378207178.py:35: UserWarning: `keep_geom_type=True` in overlay resulted in 20 dropped geometries of different geometry types than df1 has. Set `keep_geom_type=False` to retain all geometries
#   delaware_land_gdf = gpd.overlay(sldl_gdf, USmap, how='intersection')
#                                       NAME B01001_001E state  \
# 0  State House District 1 (2018), Delaware       22307    10
# 1  State House District 2 (2018), Delaware       21782    10
# 2  State House District 3 (2018), Delaware       19542    10
# 3  State House District 4 (2018), Delaware       20375    10
# 4  State House District 5 (2018), Delaware       22135    10
#
#   state legislative district (lower chamber)
# 0                                        001
# 1                                        002
# 2                                        003
# 3                                        004
# 4                                        005
# /Users/kamran/anaconda3/envs/census/lib/python3.10/site-packages/shapely/set_operations.py:133: RuntimeWarning: invalid value encountered in intersection
#   return lib.intersection(a, b, **kwargs)
# /var/folders/75/y16smf2j5032r_8n2vhxct6r0000gn/T/ipykernel_29732/2378207178.py:35: UserWarning: `keep_geom_type=True` in overlay resulted in 20 dropped geometries of different geometry types than df1 has. Set `keep_geom_type=False` to retain all geometries
#   delaware_land_gdf = gpd.overlay(sldl_gdf, USmap, how='intersection')
#                                       NAME B01001_001E state  \
# 0  State House District 1 (2018), Delaware       22262    10
# 1  State House District 2 (2018), Delaware       22198    10
# 2  State House District 3 (2018), Delaware       19796    10
# 3  State House District 4 (2018), Delaware       21154    10
# 4  State House District 5 (2018), Delaware       21808    10
#
#   state legislative district (lower chamber)
# 0                                        001
# 1                                        002
# 2                                        003
# 3                                        004
# 4                                        005
# /Users/kamran/anaconda3/envs/census/lib/python3.10/site-packages/shapely/set_operations.py:133: RuntimeWarning: invalid value encountered in intersection
#   return lib.intersection(a, b, **kwargs)
# /var/folders/75/y16smf2j5032r_8n2vhxct6r0000gn/T/ipykernel_29732/2378207178.py:35: UserWarning: `keep_geom_type=True` in overlay resulted in 19 dropped geometries of different geometry types than df1 has. Set `keep_geom_type=False` to retain all geometries
#   delaware_land_gdf = gpd.overlay(sldl_gdf, USmap, how='intersection')
