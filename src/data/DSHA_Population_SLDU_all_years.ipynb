# %%
import requests
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import os

# %%
# Load the Delaware dry land shapefile as a GeoDataFrame
USmap = gpd.read_file("/Users/kamran/Downloads/Shapefiles/cb_2018_us_state_5m/cb_2018_us_state_5m.shp")

# %% [markdown]
# # Extracting for a range of years

# %%
for i in range(2014,2022):
    year = str(i)
    
    usr_key = os.environ.get('CENSUS_API_KEY')

    host = 'https://api.census.gov/data'
    dataset_acronym = '/acs/acs5'
    g = '?get='
    variables = 'NAME,B01001_001E'
    location = '&for=state%20legislative%20district%20(upper%20chamber):*&in=state:10'

    # Put it all together in one f-string:
    query_url = f"{host}/{year}{dataset_acronym}{g}{variables}{location}&key={usr_key}"

    response = requests.get(query_url)

    # Create shapefile query URL
    shape_url = f"https://www2.census.gov/geo/tiger/TIGER{year}/SLDU/tl_{year}_10_sldu.zip"

    # Read the shapefile from the URL into a GeoPandas DataFrame
    sldu_gdf = gpd.read_file(shape_url)

    # Check if the request was successful (status code 200)
    if response.status_code == 200:

        # Convert the JSON response to a list of lists (excluding the header)
        data = response.json()[1:]

        # Convert the list of lists into a DataFrame
        columns = response.json()[0]  # Use the first row as column names
        api_data_df = pd.DataFrame(data, columns=columns)
        print(api_data_df.head())

        # Spatial intersection to retain only the parts within the dry land of Delaware
        delaware_land_gdf = gpd.overlay(sldu_gdf, USmap, how='intersection')

        # Dissolve the GeoDataFrame based on the SLDUST column to eliminate duplicates
        delaware_land_gdf = delaware_land_gdf.dissolve(by='SLDUST', aggfunc='first')

        # Merge the DataFrame with the GeoDataFrame based on the common key and modify
        output_gdf = delaware_land_gdf.merge(api_data_df, left_on="SLDUST", right_on="state legislative district (upper chamber)")
        output_gdf = output_gdf[['geometry','B01001_001E','state legislative district (upper chamber)']]
        output_gdf.rename(columns={'B01001_001E':'Estimated Population','state legislative district (upper chamber)':'District'},inplace=True)
        output_gdf = output_gdf.astype({'Estimated Population':'int64','District':'int64'})
        
        # Save the merged GeoDataFrame as a GeoJSON file
        output_file = f"./DSHA_Population_SLDU_all_years/Population_SLDU_{year}.json"
        output_gdf.to_file(output_file, driver='GeoJSON')

        # Plot the merged GeoDataFrame with the added information from the DataFrame
        fig, ax = plt.subplots(figsize=(10, 10))
        output_gdf.plot(column="Estimated Population", cmap="OrRd", legend=True, ax=ax)
        ax.set_title(f"Estimated Population in State Legislative District Upper ({year})", fontsize=16)

    else:
        print("Error: Unable to fetch data from the API.")

    plt.savefig(f"./DSHA_Population_SLDU_all_years/population_sldu_{year}.png", dpi=300)
# Out:
#                                        NAME B01001_001E state  \
# 0  State Senate District 1 (2014), Delaware       43290    10
# 1  State Senate District 5 (2014), Delaware       40993    10
# 2  State Senate District 2 (2014), Delaware       41804    10
# 3  State Senate District 3 (2014), Delaware       41340    10
# 4  State Senate District 4 (2014), Delaware       40645    10
#
#   state legislative district (upper chamber)
# 0                                        001
# 1                                        005
# 2                                        002
# 3                                        003
# 4                                        004
# /Users/kamran/anaconda3/envs/census/lib/python3.10/site-packages/shapely/set_operations.py:133: RuntimeWarning: invalid value encountered in intersection
#   return lib.intersection(a, b, **kwargs)
# /var/folders/75/y16smf2j5032r_8n2vhxct6r0000gn/T/ipykernel_29710/1500690770.py:35: UserWarning: `keep_geom_type=True` in overlay resulted in 26 dropped geometries of different geometry types than df1 has. Set `keep_geom_type=False` to retain all geometries
#   delaware_land_gdf = gpd.overlay(sldu_gdf, USmap, how='intersection')
#                                        NAME B01001_001E state  \
# 0  State Senate District 1 (2014), Delaware       44612    10
# 1  State Senate District 2 (2014), Delaware       42472    10
# 2  State Senate District 3 (2014), Delaware       40556    10
# 3  State Senate District 4 (2014), Delaware       40361    10
# 4  State Senate District 5 (2014), Delaware       40971    10
#
#   state legislative district (upper chamber)
# 0                                        001
# 1                                        002
# 2                                        003
# 3                                        004
# 4                                        005
# /Users/kamran/anaconda3/envs/census/lib/python3.10/site-packages/shapely/set_operations.py:133: RuntimeWarning: invalid value encountered in intersection
#   return lib.intersection(a, b, **kwargs)
# /var/folders/75/y16smf2j5032r_8n2vhxct6r0000gn/T/ipykernel_29710/1500690770.py:35: UserWarning: `keep_geom_type=True` in overlay resulted in 26 dropped geometries of different geometry types than df1 has. Set `keep_geom_type=False` to retain all geometries
#   delaware_land_gdf = gpd.overlay(sldu_gdf, USmap, how='intersection')
#                                        NAME B01001_001E state  \
# 0  State Senate District 1 (2016), Delaware       44553    10
# 1  State Senate District 2 (2016), Delaware       42302    10
# 2  State Senate District 3 (2016), Delaware       40473    10
# 3  State Senate District 4 (2016), Delaware       40278    10
# 4  State Senate District 5 (2016), Delaware       41127    10
#
#   state legislative district (upper chamber)
# 0                                        001
# 1                                        002
# 2                                        003
# 3                                        004
# 4                                        005
# /Users/kamran/anaconda3/envs/census/lib/python3.10/site-packages/shapely/set_operations.py:133: RuntimeWarning: invalid value encountered in intersection
#   return lib.intersection(a, b, **kwargs)
# /var/folders/75/y16smf2j5032r_8n2vhxct6r0000gn/T/ipykernel_29710/1500690770.py:35: UserWarning: `keep_geom_type=True` in overlay resulted in 27 dropped geometries of different geometry types than df1 has. Set `keep_geom_type=False` to retain all geometries
#   delaware_land_gdf = gpd.overlay(sldu_gdf, USmap, how='intersection')
#                                        NAME B01001_001E state  \
# 0  State Senate District 1 (2016), Delaware       43914    10
# 1  State Senate District 2 (2016), Delaware       43181    10
# 2  State Senate District 3 (2016), Delaware       39770    10
# 3  State Senate District 4 (2016), Delaware       41194    10
# 4  State Senate District 5 (2016), Delaware       41880    10
#
#   state legislative district (upper chamber)
# 0                                        001
# 1                                        002
# 2                                        003
# 3                                        004
# 4                                        005
# /Users/kamran/anaconda3/envs/census/lib/python3.10/site-packages/shapely/set_operations.py:133: RuntimeWarning: invalid value encountered in intersection
#   return lib.intersection(a, b, **kwargs)
# /var/folders/75/y16smf2j5032r_8n2vhxct6r0000gn/T/ipykernel_29710/1500690770.py:35: UserWarning: `keep_geom_type=True` in overlay resulted in 27 dropped geometries of different geometry types than df1 has. Set `keep_geom_type=False` to retain all geometries
#   delaware_land_gdf = gpd.overlay(sldu_gdf, USmap, how='intersection')
#                                        NAME B01001_001E state  \
# 0  State Senate District 1 (2018), Delaware       44876    10
# 1  State Senate District 2 (2018), Delaware       42153    10
# 2  State Senate District 3 (2018), Delaware       39110    10
# 3  State Senate District 4 (2018), Delaware       40878    10
# 4  State Senate District 5 (2018), Delaware       41850    10
#
#   state legislative district (upper chamber)
# 0                                        001
# 1                                        002
# 2                                        003
# 3                                        004
# 4                                        005
# /Users/kamran/anaconda3/envs/census/lib/python3.10/site-packages/shapely/set_operations.py:133: RuntimeWarning: invalid value encountered in intersection
#   return lib.intersection(a, b, **kwargs)
# /var/folders/75/y16smf2j5032r_8n2vhxct6r0000gn/T/ipykernel_29710/1500690770.py:35: UserWarning: `keep_geom_type=True` in overlay resulted in 27 dropped geometries of different geometry types than df1 has. Set `keep_geom_type=False` to retain all geometries
#   delaware_land_gdf = gpd.overlay(sldu_gdf, USmap, how='intersection')
#                                        NAME B01001_001E state  \
# 0  State Senate District 1 (2018), Delaware       45959    10
# 1  State Senate District 2 (2018), Delaware       41571    10
# 2  State Senate District 3 (2018), Delaware       38661    10
# 3  State Senate District 4 (2018), Delaware       39945    10
# 4  State Senate District 5 (2018), Delaware       42063    10
#
#   state legislative district (upper chamber)
# 0                                        001
# 1                                        002
# 2                                        003
# 3                                        004
# 4                                        005
# /Users/kamran/anaconda3/envs/census/lib/python3.10/site-packages/shapely/set_operations.py:133: RuntimeWarning: invalid value encountered in intersection
#   return lib.intersection(a, b, **kwargs)
# /var/folders/75/y16smf2j5032r_8n2vhxct6r0000gn/T/ipykernel_29710/1500690770.py:35: UserWarning: `keep_geom_type=True` in overlay resulted in 27 dropped geometries of different geometry types than df1 has. Set `keep_geom_type=False` to retain all geometries
#   delaware_land_gdf = gpd.overlay(sldu_gdf, USmap, how='intersection')
#                                        NAME B01001_001E state  \
# 0  State Senate District 1 (2018), Delaware       44477    10
# 1  State Senate District 2 (2018), Delaware       41343    10
# 2  State Senate District 3 (2018), Delaware       39367    10
# 3  State Senate District 4 (2018), Delaware       40479    10
# 4  State Senate District 5 (2018), Delaware       40613    10
#
#   state legislative district (upper chamber)
# 0                                        001
# 1                                        002
# 2                                        003
# 3                                        004
# 4                                        005
# /Users/kamran/anaconda3/envs/census/lib/python3.10/site-packages/shapely/set_operations.py:133: RuntimeWarning: invalid value encountered in intersection
#   return lib.intersection(a, b, **kwargs)
# /var/folders/75/y16smf2j5032r_8n2vhxct6r0000gn/T/ipykernel_29710/1500690770.py:35: UserWarning: `keep_geom_type=True` in overlay resulted in 27 dropped geometries of different geometry types than df1 has. Set `keep_geom_type=False` to retain all geometries
#   delaware_land_gdf = gpd.overlay(sldu_gdf, USmap, how='intersection')
#                                        NAME B01001_001E state  \
# 0  State Senate District 1 (2018), Delaware       46493    10
# 1  State Senate District 2 (2018), Delaware       40867    10
# 2  State Senate District 3 (2018), Delaware       39946    10
# 3  State Senate District 4 (2018), Delaware       40516    10
# 4  State Senate District 5 (2018), Delaware       41754    10
#
#   state legislative district (upper chamber)
# 0                                        001
# 1                                        002
# 2                                        003
# 3                                        004
# 4                                        005
# /Users/kamran/anaconda3/envs/census/lib/python3.10/site-packages/shapely/set_operations.py:133: RuntimeWarning: invalid value encountered in intersection
#   return lib.intersection(a, b, **kwargs)
# /var/folders/75/y16smf2j5032r_8n2vhxct6r0000gn/T/ipykernel_29710/1500690770.py:35: UserWarning: `keep_geom_type=True` in overlay resulted in 23 dropped geometries of different geometry types than df1 has. Set `keep_geom_type=False` to retain all geometries
#   delaware_land_gdf = gpd.overlay(sldu_gdf, USmap, how='intersection')

# %%
False = True
# Out:
#   Cell In[4], line 1
#     False = True
#     ^
# SyntaxError: cannot assign to False

# %% [markdown]
# # Extracting for a single year

# %%
year = '2020'

# %%
usr_key = os.environ.get('CENSUS_API_KEY')

host = 'https://api.census.gov/data'
dataset_acronym = '/acs/acs5'
g = '?get='
variables = 'NAME,B01001_001E'
location = '&for=state%20legislative%20district%20(upper%20chamber):*&in=state:10'

# Put it all together in one f-string:
query_url = f"{host}/{year}{dataset_acronym}{g}{variables}{location}&key={usr_key}"

response = requests.get(query_url)

# Create shapefile query URL
shape_url = f"https://www2.census.gov/geo/tiger/TIGER{year}/SLDU/tl_{year}_10_sldu.zip"

# Read the shapefile from the URL into a GeoPandas DataFrame
sldu_gdf = gpd.read_file(shape_url)

# Check if the request was successful (status code 200)
if response.status_code == 200:
    
    # Convert the JSON response to a list of lists (excluding the header)
    data = response.json()[1:]
    
    # Convert the list of lists into a DataFrame
    columns = response.json()[0]  # Use the first row as column names
    api_data_df = pd.DataFrame(data, columns=columns)
    print(api_data_df.head())
    
    # Spatial intersection to retain only the parts within the dry land of Delaware
    delaware_land_gdf = gpd.overlay(sldu_gdf, USmap, how='intersection')
    
    # Dissolve the GeoDataFrame based on the SLDUST column to eliminate duplicates
    delaware_land_gdf_dissolved = delaware_land_gdf.dissolve(by='SLDUST', aggfunc='first')
    
    # Merge the DataFrame with the GeoDataFrame based on the common key
    output_gdf = delaware_land_gdf.merge(api_data_df, left_on="SLDUST", right_on="state legislative district (upper chamber)")
    output_gdf = output_gdf[['geometry','B01001_001E','state legislative district (upper chamber)']]
    output_gdf.rename(columns={'B01001_001E':'Estimated Population','state legislative district (upper chamber)':'Senate District'},inplace=True)
    output_gdf = output_gdf.astype({'Estimated Population':'int64','District':'int64'})
    
    # Save the merged GeoDataFrame as a GeoJSON file
    output_file = f"./DSHA_Population_SLDU_all_years/Population_SLDU_{year}.json"
    output_gdf.to_file(output_file, driver='GeoJSON')
    
    # Plot the merged GeoDataFrame with the added information from the DataFrame
    fig, ax = plt.subplots(figsize=(10, 10))
    output_gdf.plot(column="Estimated Population", cmap="OrRd", legend=True, ax=ax)
    ax.set_title(f"Estimated Population in State Legislative District Upper ({year})", fontsize=16)
else:
    print("Error: Unable to fetch data from the API.")

plt.savefig(f"./DSHA_Population_SLDU_all_years/population_sldu_{year}.png", dpi=300)
